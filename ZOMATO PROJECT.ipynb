# %% [markdown]
# # Zomato Restaurant Project

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Problem Statement:</b>

# %% [markdown]
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.

# %% [markdown]
# <b>Data Storage:</b>

# %% [markdown]
# This problem statement contains two datasets- <b>Zomato.csv</b> and <b>country_code.csv</b>.
# <b>Country_code.csv</b> contains two variables:
# * Country code
# * Country name
#
# The collected data has been stored in the Comma Separated Value file <b>Zomato.csv</b>. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the
# following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
# • Restaurant Name: Name of the restaurant
# • Country Code: Country in which restaurant is located
# • City: City in which restaurant is located
# • Address: Address of the restaurant
# • Locality: Location in the city
# • Locality Verbose: Detailed description of the locality
# • Longitude: Longitude coordinate of the restaurant&#39;s location
# • Latitude: Latitude coordinate of the restaurant&#39;s location
# • Cuisines: Cuisines offered by the restaurant
# • Average Cost for two: Cost for two people in different currencies
# • Currency: Currency of the country
# • Has Table booking: yes/no
# • Has Online delivery: yes/ no
# • Is delivering: yes/ no
# • Switch to order menu: yes/no
# • Price range: range of price of food
# • Aggregate Rating: Average rating out of 5
# • Rating color: depending upon the average rating color
# • Rating text: text on the basis of rating of rating
# • Votes: Number of ratings casted by people

# %% [markdown]
# <b>Problem statement :</b>
#
# In this dataset predict 2 things –
# 1) Average Cost for two
# 2) Price range

# %% [markdown]
# <b>Hint :</b>
# Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets

# %% [markdown]
# <b>Downlaod Files:</b>
#
# https://github.com/dsrscientist/dataset4/blob/main/Country-Code.xlsx
# https://github.com/dsrscientist/dataset4/blob/main/zomato.csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv(r'zomato.csv', encoding='unicode_escape')
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df2 = pd.read_excel(r'Country-Code.xlsx')
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
data = pd.merge(df1, df2, on = 'Country Code', how = 'left')
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
data.sample(3)
# Out:
#       Restaurant ID    Restaurant Name  Country Code       City  \
# 1180       18352271    Lavi Foji Dhaba             1    Gurgaon
# 731           56464   Glen's Bakehouse             1  Bangalore
# 6212         311379  Ganesh Restaurant             1  New Delhi
#
#                                                 Address       Locality  \
# 1180  Shop 4, B Block, Vicky Market, Ardee City, Gur...     Ardee City
# 731          297, 100 Feet Road, Indiranagar, Bangalore    Indiranagar
# 6212  BG-8, DDA Central Market, Paschim Vihar, New D...  Paschim Vihar
#
#               Locality Verbose  Longitude   Latitude                Cuisines  \
# 1180       Ardee City, Gurgaon  77.081492  28.440652            North Indian
# 731     Indiranagar, Bangalore  77.640625  12.979096  Bakery, Desserts, Cafe
# 6212  Paschim Vihar, New Delhi  77.100580  28.662677   North Indian, Mughlai
#
#       ...  Has Table booking Has Online delivery Is delivering now  \
# ...

# %%
data.shape
# Out:
# (9551, 22)

# %% [markdown]
# <b>The dataset consists of 9551 rows and 22 columns.</b>

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# <b>The dataset consists of 22 columns. Here, the columns 'Average Cost for two' and 'Price range' are the target variables and the remaining columns are the features.</b>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Let's check the number of unique values present in the dataset

data.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %%
# Let's drop the column 'Restaurant ID' as it contains only unique values, and serves no purpose in our analysis

data.drop('Restaurant ID', axis=1, inplace=True)

# %%
# Let's drop the column 'Locality Verbose', as we already have the column 'Location'

data.drop('Locality Verbose', axis=1, inplace=True)

# %%
# Let's check the null values

data.isnull().sum()
# Out:
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
plt.figure(figsize=(15,5))

sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b>From the heat map above, we can confirm that null values are present in the dataset.</b>

# %%
from sklearn.impute import SimpleImputer

SI = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
data['Cuisines'] = SI.fit_transform(data['Cuisines'].values.reshape(-1,1))

# %%
# Let's check the null values again

data.isnull().sum()
# Out:
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
plt.figure(figsize=(15,5))

sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.dtypes
# Out:
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# # Univariate Analysis

# %%
sns.countplot(x='Country Code',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, maximum restaurants are located in the country with country code 1.</b>

# %%
sns.countplot(x='Price range',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, majority of the times the price range is 1, followed by 2.</b>

# %%
sns.countplot(y='Currency',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, majority of the times, the currency used is Indian Rupees(INR), followed by Dollar($).</b>

# %%
sns.countplot(x='Has Table booking',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, majority of the times, customers have no table booking.</b>

# %%
sns.countplot(x='Has Online delivery',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, majority of the times, Zomato provides no online delivery.</b>

# %%
# Let's see which countries have online delivery option

od = data[data['Has Online delivery']=='Yes'].Country.value_counts()

# %%
od.plot.pie(autopct = '%1.1f%%')
plt.title('Country has online delivery')
plt.show()

# %% [markdown]
# <b>As we can see, 98.9% of the online deliveries are made in India.</b>

# %%
sns.countplot(x='Is delivering now',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, majority of the times, Zomato does not deliver right away.</b>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Aggregate rating',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, majority of the customers have given an aggregate rating of zero. The average rating is around 3.2.</b>

# %%
sns.countplot(x='Rating color',data=data,)
plt.show()

# %% [markdown]
# <b>As we can see, majority of the times, Orange is used as the rating colour.</b>

# %%
sns.countplot(x='Rating text',data=data,)
plt.show()

# %% [markdown]
# <b>As we can see, majority of the times, the rating text used is Average, followed by Good.
# There are also a good number of cases, where the customer does'nt give any rating.</b>

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Country',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, Zomato has its business mostly in India.</b>

# %%
# Now, let's see in which city of India, does Zomato have maximum business

city_values = data.City.value_counts().values
city_labels = data.City.value_counts().index

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# <b>As we can see, Zomato is the most popular in New Delhi, followed by Gurgaon.</b>

# %%
# Let's find out the top 10 Cuisines

cuisine_val = data.Cuisines.value_counts().values
cuisine_label = data.Cuisines.value_counts().index

# %%
plt.pie(cuisine_val[:10],labels = cuisine_label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# <b>As we can see, majority of the customers prefer North Indian Cuisine, followed by Chinese.</b>

# %%
# Let's find the top 10 locations

val = data.Locality.value_counts().values
label = data.Locality.value_counts().index

# %%
plt.pie(val[:10],labels=label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# <b>As we can see, majority of the times, Zomato is located in Connaught Palace, followed by Rajouri Garden.</b>

# %%
sns.distplot(data['Average Cost for two'])
plt.show()

# %% [markdown]
# <b>As we can see, majority of the times, Average Cost for two is affordable.</b>

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(15,6))
df_good = data.sort_values(by="Average Cost for two",ascending=False)
sns.barplot(x="Country",y="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# <b>As we can see, Indonesia has high Average Cost for two, as compared to other countries.</b>

# %%
plt.figure(figsize=(20,6))
df_good = data.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(x="Restaurant Name", y="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# <b>These are the top 10 restaurants with the least Average Price for two. The restaurant with the least average price is Talaga Sampireun, followed by MONKS.</b>

# %%
df_good = data.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(x="Average Cost for two", y="City", data=df_good)
plt.show()

# %% [markdown]
# <b>As we can see, Jakarta has the highest Average Price for two, followed by Tangerang and Bogor.</b>

# %%
sns.boxplot(x='Has Online delivery',y='Votes',data=data)
plt.title('Has Online delivery VS Votes')
plt.show()

# %% [markdown]
# <b>As we can see, Restaurants accepting online orders tend to get more votes from customers as there is a rating option poping up after each order on Zomato application.</b>

# %%
data.groupby('Restaurant Name')['Aggregate rating'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# <b>As we can see, these are the top 10 restaurant name where most of the coustomers gives good aggregate rating.</b>

# %%
sns.boxplot(x='Has Online delivery',y='Average Cost for two',data=data)
plt.title('Has Online delivery VS Average Cost for two')
plt.show()

# %% [markdown]
# <b>As we can see, Average Cost for two is not affected by Online delivery system.</b>

# %%
data.groupby('Restaurant Name')['Votes'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# <b>As we can see, these are the top 10 Restaurant Nameson on the basis of Votes.
# Toit is at the leading position , followed by Hauz Khas Social.</b>

# %%
sns.scatterplot(x='Average Cost for two',y='Longitude',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, there is no linear relation between Longitude and average Cost for two.</b>

# %%
sns.scatterplot(x='Average Cost for two',y='Latitude',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, there is no linear relation between Latitude and average Cost for two.</b>

# %%
rating = data.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating count'})

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Aggregate rating', y='Rating count', data=rating)
plt.show()

# %% [markdown]
# <b>As we can see see, more than 2000 customers have given a rating of zero.
# More than 500 customers have given an aggregate rating of around 3.2.
# Less than 100 customers have given the best rating, i.e., 4.9</b>

# %%
plt.figure(figsize=(10,6))
df_good = data.sort_values(by="Latitude",ascending=False).iloc[0:10,:]
sns.barplot(y="Restaurant Name",x="Latitude",data=df_good)
plt.show()

# %% [markdown]
# <b>As we can see, all the restaurants are located in the same Latitude.</b>

# %%
sns.barplot(x='Price range',y='Average Cost for two',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, when the Price range is 3, the Average Cost for two is higher.</b>

# %%
sns.barplot(x='Rating text',y='Average Cost for two',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, when the Rating text is excellent, the Average Cost for two is higher.</b>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating text',data=rating)
plt.show()

# %% [markdown]
# <b>As we can see, majority of the restaurants have the Rating text as excellent and an Aggregate rating of more than 4.5.
# The restaurants whose Rating text is very good, have an aggregate rating of more than 4.</b>

# %%
# Find the countries name that has given 0 rating

data[data['Rating color']=='White'].groupby(['Aggregate rating','Country']).size().reset_index()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %% [markdown]
# <b>As we can see, majority of the Indian customers have given an aggregate rating of 0.</b>

# %%
Delhi = data[(data.City == 'New Delhi')]
top_locality = Delhi.Locality.value_counts().head(10)
plt.figure(figsize=(12,6))
sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])
plt.title('Resturants Online Delivery')
plt.show()

# %% [markdown]
# <b>As we can see, there is no Online delivery in majority of the locations.
# But, Malviya Nagar has a good Online delivery system, followed by Connaught Palace.</b>

# %%
sns.countplot(x='Has Online delivery',hue='Has Table booking',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, the restaurants which do not provide Online delivery, also most of the times do not provide the option of Table booking.</b>

# %%
sns.countplot(x='Rating color',hue='Price range',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, when the Rating color is Orange, the Price range is 1, followed by 2.</b>

# %%
sns.scatterplot(x='Votes',y='Average Cost for two',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, Votes has no linear relationship with Average cost for two.</b>

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',data=data)
plt.show()

# %% [markdown]
# <b>As we can see, there is a very weak linear relationship between Votes and Aggregate rating.</b>

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='Aggregate rating',y='Average Cost for two',hue='Has Online delivery',data=data)
plt.show()

# %% [markdown]
# <b>As can see, very few restaurant have an option of Online delivery, and such restaurants have an good aggregate rating.</b>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count',hue='Rating color',data=rating, palette=['blue','red','orange','yellow','green','darkgreen'])
plt.show()

# %% [markdown]
# <b>As we can see, majority of the customers have given a rating of zero. The average Aggregate rating is 3.2.</b>

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="Country", y="Average Cost for two", hue="Has Online delivery",data=data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <b>As we can see, although Indonesia has the highest Average Cost for two, they do not have the option of Online delivery.</b>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="Average Cost for two", y="Aggregate rating", hue='Price range', data=Delhi)

plt.xlabel("Average Cost for two")
plt.ylabel("Aggregate rating")
plt.title('Rating vs Cost of Two')
plt.show()

# %% [markdown]
# <b>As we can see, there is no linear relationship between Price range and Aggregate rating.</b>

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',data=data,hue='Has Online delivery')
plt.show()

# %% [markdown]
# <b>As can see, majority of the restaurants are having an aggregate rating of more than 4, have an Online delivery option.</b>

# %% [markdown]
# # Encoding the categorical columns using Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

for col in data[data.columns[data.dtypes == 'object']]:
    data[col] = le.fit_transform(data[col])

# %% [markdown]
# # Statistical Description of the Dataset

# %%
data.describe()
# Out:
#        Restaurant Name  Country Code         City      Address     Locality  \
# count      9551.000000   9551.000000  9551.000000  9551.000000  9551.000000
# mean       3653.204586     18.365616    78.301434  4542.439430   658.128468
# std        2142.917876     56.750546    23.198915  2565.717005   315.866515
# min           0.000000      1.000000     0.000000     0.000000     0.000000
# 25%        1777.500000      1.000000    76.000000  2323.500000   381.000000
# 50%        3595.000000      1.000000    88.000000  4610.000000   696.000000
# 75%        5485.500000      1.000000    88.000000  6746.500000   921.000000
# max        7445.000000    216.000000   140.000000  8917.000000  1207.000000
#
#          Longitude     Latitude     Cuisines  Average Cost for two  \
# count  9551.000000  9551.000000  9551.000000           9551.000000
# mean     64.126574    25.854381   989.461732           1199.210763
# std      41.467058    11.007935   514.176108          16121.183073
# ...

# %%
# Now, let's visualize the statistics of the columns using Heatmap

plt.figure(figsize=(25,8))

sns.heatmap(data.describe(), linewidths=0.2, fmt='0.2f', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation between features and labels

# %%
data.corr()
# Out:
#                       Restaurant Name  Country Code      City   Address  \
# Restaurant Name              1.000000      0.020012 -0.001399  0.000763
# Country Code                 0.020012      1.000000 -0.181728 -0.220342
# City                        -0.001399     -0.181728  1.000000 -0.019763
# Address                      0.000763     -0.220342 -0.019763  1.000000
# Locality                     0.004322     -0.120075  0.096444  0.159555
# Longitude                   -0.001920     -0.698299  0.117391  0.185801
# Latitude                     0.009922      0.019792 -0.004301 -0.038654
# Cuisines                     0.051679     -0.132902  0.026614  0.023944
# Average Cost for two         0.019241      0.043225 -0.028838  0.022749
# Currency                     0.009669     -0.033466 -0.071996  0.069499
# Has Table booking            0.041173     -0.061682 -0.003762  0.006428
# Has Online delivery          0.028082     -0.154605  0.012723  0.029874
# ...

# %% [markdown]
# # Correlation between features and labels using Heatmap

# %%
plt.figure(figsize=(25,10))

sns.heatmap(data.corr(), linewidths=0.1, fmt='.2g', annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
data.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar')
plt.xlabel('Features',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.title('Correlation between target and features using Bar plot',fontsize=18)
plt.show()

# %% [markdown]
# # Let's check the distribution of data

# %%
plt.figure(figsize=(25,30))
plotnumber = 1

for column in data:
    if plotnumber <=20:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# # Outliers Detection

# %%
plt.figure(figsize=(25,30))
plotnumber = 1

for column in data:
    if plotnumber <=20:
        plt.subplot(5,4,plotnumber)
        ax = sns.boxplot(data=data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %%
# Let's remove the outliers only from continuous data

features = data[['Average Cost for two', 'Votes']]

from scipy.stats import zscore

z = np.abs(zscore(features))
z
# Out:
#       Average Cost for two     Votes
# 0                 0.006154  0.365202
# 1                 0.000049  1.009168
# 2                 0.173743  0.262911
# 3                 0.018659  0.483766
# 4                 0.018659  0.167595
# ...                    ...       ...
# 9546              0.069428  1.467151
# 9547              0.067878  2.039049
# 9548              0.063845  1.171903
# 9549              0.066947  1.729853
# 9550              0.070979  1.009168
#
# [9551 rows x 2 columns]

# %%
# Now, let's create a new dataframe

data_new = data[(z<3).all(axis=1)]
data_new
# Out:
#       Restaurant Name  Country Code  City  Address  Locality   Longitude  \
# 0                3749           162    73     8685       171  121.027535
# 1                3173           162    73     6055       593  121.014101
# 2                2897           162    75     4684       308  121.056831
# 3                4707           162    75     8690       862  121.056475
# 4                5523           162    75     8689       862  121.057508
# ...               ...           ...   ...      ...       ...         ...
# 9546             4443           208   140     5926       517   28.977392
# 9547             1311           208   140     5962       552   29.041297
# 9548             3069           208   140     5966       554   29.034640
# 9549              513           208   140     5967       554   29.036019
# 9550             7240           208   140     4258       670   29.026016
#
#        Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# ...

# %%
print(data.shape) 
print(data_new.shape)
# Out:
# (9551, 20)
# (9362, 20)

# %% [markdown]
# # Percentage data loss

# %%
loss_percent = (9551-9362)/9551*100
print(loss_percent, '%')
# Out:
# 1.978850382158936 %

# %% [markdown]
# <b>As the data loss is just 1.97%, we can proceed further.</b>

# %% [markdown]
# # Model 1

# %% [markdown]
# # Predicting Average Price for two

# %% [markdown]
# # Separating dependent and independent variables

# %%
x = data_new.drop('Average Cost for two', axis=1)

y = data_new['Average Cost for two']

# %%
x.shape
# Out:
# (9362, 19)

# %%
y.shape
# Out:
# (9362,)

# %% [markdown]
# # Data Standardization using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#       Restaurant Name  Country Code      City   Address  Locality  Longitude  \
# 0            0.046028      2.546808 -0.234817  1.608777 -1.556831   1.377696
# 1           -0.223104      2.546808 -0.234817  0.584353 -0.216997   1.377371
# 2           -0.352063      2.546808 -0.148206  0.050327 -1.121862   1.378405
# 3            0.493647      2.546808 -0.148206  1.610725  0.637068   1.378396
# 4            0.874917      2.546808 -0.148206  1.610335  0.637068   1.378421
# ...               ...           ...       ...       ...       ...        ...
# 9357         0.370294      3.360908  2.666651  0.534105 -0.458294  -0.848838
# 9358        -1.093111      3.360908  2.666651  0.548128 -0.347171  -0.847293
# 9359        -0.271698      3.360908  2.666651  0.549686 -0.340821  -0.847454
# 9360        -1.465971      3.360908  2.666651  0.550075 -0.340821  -0.847420
# 9361         1.677173      3.360908  2.666651 -0.115606  0.027475  -0.847662
#
# ...

# %% [markdown]
# <b>The data has been scaled now.</b>

# %% [markdown]
# # Checking VIF values to solve multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()

vif['VIF values']= [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values              Features
# 0     1.008725       Restaurant Name
# 1    48.277013          Country Code
# 2     1.081832                  City
# 3     1.106128               Address
# 4     1.068078              Locality
# 5     5.031278             Longitude
# 6     3.037982              Latitude
# 7     1.045210              Cuisines
# 8     1.294200              Currency
# 9     1.482410     Has Table booking
# 10    1.168629   Has Online delivery
# 11    1.014266     Is delivering now
# 12         NaN  Switch to order menu
# 13    1.949696           Price range
# 14    1.948000      Aggregate rating
# 15    1.221375          Rating color
# 16    1.425964           Rating text
# 17    1.613811                 Votes
# 18   66.487853               Country

# %%
x.drop('Country', axis=1, inplace=True)
x.drop('Switch to order menu', axis=1, inplace=True)

# %%
# Now, let's check the VIF again, after removing the column 'Temp3pm'

vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF values             Features
# 0     1.008720      Restaurant Name
# 1     2.738895         Country Code
# 2     1.077355                 City
# 3     1.099983              Address
# 4     1.067098             Locality
# 5     2.556483            Longitude
# 6     1.152970             Latitude
# 7     1.045075             Cuisines
# 8     1.288482             Currency
# 9     1.481033    Has Table booking
# 10    1.168591  Has Online delivery
# 11    1.014266    Is delivering now
# 12    1.912280          Price range
# 13    1.947664     Aggregate rating
# 14    1.218314         Rating color
# 15    1.425920          Rating text
# 16    1.572913                Votes

# %% [markdown]
# # Selecting Kbest Features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
best_features = SelectKBest(score_func = f_classif, k = 'all')
fit = best_features.fit(x,y)
datascores = pd.DataFrame(fit.scores_)
datacolumns = pd.DataFrame(x.columns)

# %%
fit = best_features.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
datacolumns = pd.DataFrame(x.columns)
datacolumns.head()
featureScores = pd.concat([datacolumns,datascores],axis = 1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(35,'Score'))
# Out:
#                 Feature       Score
# 12          Price range  418.202989
# 1          Country Code  272.264460
# 5             Longitude  142.353602
# 9     Has Table booking   80.635590
# 8              Currency   29.041295
# 16                Votes   25.818126
# 13     Aggregate rating   22.275744
# 6              Latitude   15.805349
# 10  Has Online delivery   11.752010
# 3               Address    7.795143
# 15          Rating text    7.144425
# 2                  City    4.863372
# 14         Rating color    4.044857
# 7              Cuisines    3.832948
# 4              Locality    3.379470
# 11    Is delivering now    2.063234
# 0       Restaurant Name    1.358221

# %%
x_best = x.drop(columns=['Restaurant Name','Is delivering now']).copy()

# %% [markdown]
# # Checking for Skewness

# %%
data.skew()
# Out:
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.307425
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %%
from sklearn.preprocessing import power_transform

x = power_transform(x_best,method='yeo-johnson')

# %%
skewness_check = pd.DataFrame(x)

# %%
skewness_check.skew()
# Out:
# 0     2.836312
# 1     0.532634
# 2    -0.007737
# 3    -0.037826
# 4     2.219168
# 5     1.349365
# 6    -0.061157
# 7    -0.164795
# 8     2.382516
# 9     1.120081
# 10    0.269597
# 11   -0.080241
# 12   -0.022619
# 13    0.147742
# 14    0.620989
# dtype: float64

# %% [markdown]
# # Finding best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# %%
from sklearn.ensemble import RandomForestRegressor

maxAccu=0
maxRS=0

for i in range(1,200):
    xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.30, random_state=i)
    mod = RandomForestRegressor()
    mod.fit(xtrain, ytrain)
    pred = mod.predict(xtest)
    acc = r2_score(ytest, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.8968079263259081  on Random_state  150

# %% [markdown]
# # Train Test Split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.30, random_state=maxRS)

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

RFR = RandomForestRegressor()
RFR.fit(xtrain, ytrain)
pred_RFR = RFR.predict(xtest)

print('R2_Score:', r2_score(ytest,pred_RFR))
print('MAE:', metrics.mean_absolute_error(ytest, pred_RFR))
print('MSE:', metrics.mean_squared_error(ytest, pred_RFR))
print("RMSE:", np.sqrt(metrics.mean_squared_error(ytest, pred_RFR)))
print("CV score:", cross_val_score(RFR, x, y, cv=5).mean())
# Out:
# R2_Score: 0.8900472454918321
# MAE: 101.64762786282189
# MSE: 37742.814372510984
# RMSE: 194.275099723333
# CV score: 0.6830912059432515

# %% [markdown]
# # Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor()

gbr.fit(xtrain, ytrain)
predgbr = gbr.predict(xtest)

print('R2_Score:',r2_score(ytest,predgbr))
print('MAE:',metrics.mean_absolute_error(ytest, predgbr))
print('MSE:',metrics.mean_squared_error(ytest, predgbr))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predgbr)))
print("CV score",cross_val_score(gbr,x,y,cv=5).mean())
# Out:
# R2_Score: 0.854051256035329
# MAE: 114.05674085424855
# MSE: 50098.939094340785
# RMSE: 223.82792295498072
# CV score 0.715749806251898

# %% [markdown]
# # Bagging Regressor

# %%
from sklearn.ensemble import BaggingRegressor

br = BaggingRegressor()

br.fit(xtrain, ytrain)
predbr = br.predict(xtest)

print('R2_Score:',r2_score(ytest,predbr))
print('MAE:',metrics.mean_absolute_error(ytest, predbr))
print('MSE:',metrics.mean_squared_error(ytest, predbr))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predbr)))
print("CV score",cross_val_score(br,x,y,cv=5).mean())
# Out:
# R2_Score: 0.8778854428746997
# MAE: 105.26784146196749
# MSE: 41917.52250662553
# RMSE: 204.7376919539378
# CV score 0.6947638664351603

# %% [markdown]
# # XGB Regressor

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor()

xgb.fit(xtrain, ytrain)
predxgb = xgb.predict(xtest)

print('R2_Score:',r2_score(ytest,predxgb))
print('MAE:',metrics.mean_absolute_error(ytest, predxgb))
print('MSE:',metrics.mean_squared_error(ytest, predxgb))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predxgb)))
print("CV score",cross_val_score(xgb,x,y,cv=5).mean())
# Out:
# R2_Score: 0.8794772623724627
# MAE: 105.4800092851025
# MSE: 41371.108293654164
# RMSE: 203.3988896077217
# CV score 0.7659375248100497

# %% [markdown]
# # Extra Trees Regressor

# %%
from sklearn.ensemble import ExtraTreesRegressor

xtr = ExtraTreesRegressor()

xtr.fit(xtrain, ytrain)
predxtr = xtr.predict(xtest)

print('R2_Score:',r2_score(ytest,predxtr))
print('MAE:',metrics.mean_absolute_error(ytest, predxtr))
print('MSE:',metrics.mean_squared_error(ytest, predxtr))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, predxtr)))
print("CV score",cross_val_score(xtr,x,y,cv=5).mean())
# Out:
# R2_Score: 0.8666315787673311
# MAE: 106.63325382698469
# MSE: 45780.568101779994
# RMSE: 213.9639411250877
# CV score 0.7591421696179662

# %% [markdown]
# <b>As we can see, XGB Regressor is the best model.</b>

# %% [markdown]
# # Hyperparameter Tuning

# %%
# Now, let's perform Hyperparameter Tuning for XGB Regressor

from sklearn.model_selection import GridSearchCV


parameters = {'max_depth': [3, 6, 10],
              'learning_rate': [0.01, 0.1, 0.2],
              'subsample': np.arange(0.5, 1.0),
              'n_estimators': [100, 250, 500]}

# %%
GCV = GridSearchCV(XGBRegressor(), parameters, cv=5)

# %%
GCV.fit(xtrain, ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
GCV.best_params_
# Out:
# {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500, 'subsample': 0.5}

# %%
# Creating the Final Model

mod = XGBRegressor(learning_rate = 0.01, max_depth = 10, n_estimators = 500, subsample = 0.5)
mod.fit(xtrain, ytrain)
pred = mod.predict(xtest)
print('R2_score:',r2_score(ytest, pred)*100)
print('MAE:',metrics.mean_absolute_error(ytest, pred))
print('MSE:',metrics.mean_squared_error(ytest, pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(ytest, pred)))
# Out:
# R2_score: 88.66223015959065
# MAE: 100.23137719659205
# MSE: 38918.47406633507
# RMSE: 197.27765729127833

# %% [markdown]
# <b>After Hyperparameter tuning, we gopt an accuracy score of 88.66.</b>

# %%
plt.figure(figsize=(16,4))
plt.scatter(x=ytest, y=pred, color='r')
plt.plot(ytest,ytest, color='g')
plt.xlabel('Actual Average Cost for two',fontsize=15)
plt.ylabel('Predicted Average Cost for two',fontsize=15)
plt.title('XGB Regressor',fontsize=20)
plt.show()

# %% [markdown]
# # Saving the Model

# %%
import joblib

joblib.dump(mod, 'Average Cost for two.pkl')
# Out:
# ['Average Cost for two.pkl']

# %%
model=joblib.load('Average Cost for two.pkl')

#Prediction
prediction = model.predict(xtest)
prediction
# Out:
# array([  28.326344, 2442.8237  ,  304.7331  , ...,  277.921   ,
#         357.6517  ,  209.7443  ], dtype=float32)

# %%
pd.DataFrame([model.predict(xtest)[:],ytest[:]],index=['Predicted','Original']).T
# Out:
#         Predicted  Original
# 0       28.326344      25.0
# 1     2442.823730    2500.0
# 2      304.733093     300.0
# 3      312.354095     300.0
# 4     2289.851562    2100.0
# ...           ...       ...
# 2804   624.591187     450.0
# 2805   572.622925     500.0
# 2806   277.920990     250.0
# 2807   357.651703     400.0
# 2808   209.744293     200.0
#
# [2809 rows x 2 columns]

# %% [markdown]
# # ----------------------------------------------------------------------------------------------

# %% [markdown]
# # Model 2

# %% [markdown]
# # Predicting Price range

# %% [markdown]
# # Separating dependent and independent variables

# %%
x = data_new.drop('Price range', axis=1)

y = data_new['Price range']

# %% [markdown]
# # Data Standardization using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#       Restaurant Name  Country Code      City   Address  Locality  Longitude  \
# 0            0.046028      2.546808 -0.234817  1.608777 -1.556831   1.377696
# 1           -0.223104      2.546808 -0.234817  0.584353 -0.216997   1.377371
# 2           -0.352063      2.546808 -0.148206  0.050327 -1.121862   1.378405
# 3            0.493647      2.546808 -0.148206  1.610725  0.637068   1.378396
# 4            0.874917      2.546808 -0.148206  1.610335  0.637068   1.378421
# ...               ...           ...       ...       ...       ...        ...
# 9357         0.370294      3.360908  2.666651  0.534105 -0.458294  -0.848838
# 9358        -1.093111      3.360908  2.666651  0.548128 -0.347171  -0.847293
# 9359        -0.271698      3.360908  2.666651  0.549686 -0.340821  -0.847454
# 9360        -1.465971      3.360908  2.666651  0.550075 -0.340821  -0.847420
# 9361         1.677173      3.360908  2.666651 -0.115606  0.027475  -0.847662
#
# ...

# %% [markdown]
# <b>The data has been scaled now.</b>

# %% [markdown]
# # Checking VIF values to solve multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()

vif['VIF values']= [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values              Features
# 0     1.007780       Restaurant Name
# 1    47.202433          Country Code
# 2     1.081009                  City
# 3     1.113228               Address
# 4     1.069018              Locality
# 5     5.029649             Longitude
# 6     3.036659              Latitude
# 7     1.043427              Cuisines
# 8     1.829245  Average Cost for two
# 9     1.296729              Currency
# 10    1.608398     Has Table booking
# 11    1.175432   Has Online delivery
# 12    1.014170     Is delivering now
# 13         NaN  Switch to order menu
# 14    1.905303      Aggregate rating
# 15    1.223342          Rating color
# 16    1.420572           Rating text
# 17    1.598391                 Votes
# 18   65.332329               Country

# %%
x.drop('Country', axis=1, inplace=True)
x.drop('Switch to order menu', axis=1, inplace=True)

# %%
# Now, let's check the VIF again, after removing the column 'Temp3pm'

vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF values              Features
# 0     1.007696       Restaurant Name
# 1     2.784630          Country Code
# 2     1.077240                  City
# 3     1.105234               Address
# 4     1.068066              Locality
# 5     2.543528             Longitude
# 6     1.087823              Latitude
# 7     1.043396              Cuisines
# 8     1.825872  Average Cost for two
# 9     1.292572              Currency
# 10    1.602566     Has Table booking
# 11    1.175358   Has Online delivery
# 12    1.014146     Is delivering now
# 13    1.897673      Aggregate rating
# 14    1.220986          Rating color
# 15    1.420156           Rating text
# 16    1.567430                 Votes

# %% [markdown]
# # Balancing the dataset using SMOTE

# %%
y.value_counts()
# Out:
# 1    4437
# 2    3075
# 3    1297
# 4     553
# Name: Price range, dtype: int64

# %%
from imblearn.over_sampling import SMOTE as sm

smt_x,smt_y = sm().fit_resample(x,y)

# %%
smt_y.value_counts()
# Out:
# 3    4437
# 4    4437
# 2    4437
# 1    4437
# Name: Price range, dtype: int64

# %%
sns.countplot(smt_y)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %% [markdown]
# # Finding best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn import metrics

# %%
from sklearn.linear_model import LogisticRegression

maxAccu = 0
maxRS = 0
for i in range(1,200):
    xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.30, random_state =i)
    LR = LogisticRegression()
    LR.fit(xtrain, ytrain)
    pred = LR.predict(xtest)
    acc=accuracy_score(ytest, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ", maxAccu, " on Random_state ", maxRS)
# Out:
# Best accuracy is  0.9081523673905304  on Random_state  151

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=maxRS)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8580281690140845

# %%
def metric_score(clf, x_train_ns,x_test,y_train_ns,y_test, train=True):
    if train:
        
        y_pred = clf.predict(x_train_ns)

        print("\n========================== Train Result=============================")

        print(f"Accuracy Score: {accuracy_score(y_train_ns, y_pred) * 100:.2f}%")

    
    elif train==False:
        pred = clf.predict(x_test)
        
        print("\n==========================Test Result=======================")
        print(f"Accuracy Score: {accuracy_score(y_test,pred) * 100:.2f}%")
        
        print("\n \n Test Classification Report \n", classification_report(y_test, pred, digits=2))
        
        print('\n Confusion Matrix: \n',confusion_matrix(y_test,pred))

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(x_train,y_train)

metric_score(rf,x_train,x_test,y_train, y_test, train=True)

metric_score(rf,x_train,x_test,y_train, y_test, train=False)
# Out:
# ========================== Train Result=============================
# Accuracy Score: 100.00%
#
# ==========================Test Result=======================
# Accuracy Score: 98.87%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99      1329
#            2       0.99      0.98      0.99      1314
#            3       0.98      0.98      0.98      1352
#            4       0.99      1.00      0.99      1330
#
#     accuracy                           0.99      5325
#    macro avg       0.99      0.99      0.99      5325
# weighted avg       0.99      0.99      0.99      5325
#
#
#  Confusion Matrix:
#  [[1317   10    2    0]
#  [   3 1293   18    0]
#  [   0    8 1331   13]
#  [   0    0    6 1324]]

# %% [markdown]
# # Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)

metric_score(gbc,x_train,x_test,y_train, y_test, train=True)

metric_score(gbc,x_train,x_test,y_train, y_test, train=False)
# Out:
# ========================== Train Result=============================
# Accuracy Score: 98.45%
#
# ==========================Test Result=======================
# Accuracy Score: 97.58%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      1.00      1329
#            2       0.98      0.98      0.98      1314
#            3       0.96      0.96      0.96      1352
#            4       0.97      0.97      0.97      1330
#
#     accuracy                           0.98      5325
#    macro avg       0.98      0.98      0.98      5325
# weighted avg       0.98      0.98      0.98      5325
#
#
#  Confusion Matrix:
#  [[1321    8    0    0]
#  [   4 1291   19    0]
#  [   0   21 1296   35]
#  [   0    0   42 1288]]

# %% [markdown]
# # Support Vector Machine Classifier

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train,y_train)

metric_score(svc,x_train,x_test,y_train, y_test, train=True)

metric_score(svc,x_train,x_test,y_train, y_test, train=False)
# Out:
# ========================== Train Result=============================
# Accuracy Score: 94.07%
#
# ==========================Test Result=======================
# Accuracy Score: 92.47%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       0.98      0.93      0.96      1329
#            2       0.91      0.91      0.91      1314
#            3       0.89      0.89      0.89      1352
#            4       0.93      0.96      0.95      1330
#
#     accuracy                           0.92      5325
#    macro avg       0.93      0.92      0.92      5325
# weighted avg       0.93      0.92      0.92      5325
#
#
#  Confusion Matrix:
#  [[1242   55   26    6]
#  [  28 1195   85    6]
#  [   0   60 1206   86]
#  [   0    6   43 1281]]

# %% [markdown]
# # KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(x_train,y_train)

metric_score(knn,x_train,x_test,y_train, y_test, train=True)

metric_score(knn,x_train,x_test,y_train, y_test, train=False)
# Out:
# ========================== Train Result=============================
# Accuracy Score: 90.80%
#
# ==========================Test Result=======================
# Accuracy Score: 83.79%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       0.82      0.77      0.79      1329
#            2       0.73      0.71      0.72      1314
#            3       0.87      0.88      0.87      1352
#            4       0.93      0.99      0.96      1330
#
#     accuracy                           0.84      5325
#    macro avg       0.84      0.84      0.84      5325
# weighted avg       0.84      0.84      0.84      5325
#
#
#  Confusion Matrix:
#  [[1020  275   25    9]
#  [ 215  938  140   21]
#  [  10   77 1193   72]
#  [   0    0   19 1311]]

# %% [markdown]
# # Cross-Validation

# %%
from sklearn.model_selection import cross_val_score


print("Cross validation score of LogisticRegression() is:", cross_val_score(LR,x,y,cv=5).mean())
print("Cross validation score of RandomForestClassifier() is:", cross_val_score(rf,x,y,cv=5).mean())
print("Cross validation score of GradientBoostingRegression() is:", cross_val_score(LR,x,y,cv=5).mean())
print("Cross validation score of SVC() is:", cross_val_score(svc,x,y,cv=5).mean())
print("Cross validation score of KNeighborsClassifier() is:", cross_val_score(knn,x,y,cv=5).mean())
# Out:
# Cross validation score of LogisticRegression() is: 0.8746106388124542
# Cross validation score of RandomForestClassifier() is: 0.8554050246188527
# Cross validation score of GradientBoostingRegression() is: 0.8746106388124542
# Cross validation score of SVC() is: 0.8475968668574113
# Cross validation score of KNeighborsClassifier() is: 0.6119670098247247

# %% [markdown]
# <b>As we can see, Random Forest Classifier is the best model.</b>

# %% [markdown]
# # Hyperparameter Tuning

# %%
# Now, let's perform Hyperparameter Tuning for Random Forest Classifier

from sklearn.model_selection import GridSearchCV


parameters = {'max_depth': [10, 20, 30, 40],
              'max_features': ['auto', 'sqrt'],
              'min_samples_leaf': [1, 2, 4],
              'min_samples_split': [2, 5, 10]}

# %%
GCV = GridSearchCV(RandomForestClassifier(), parameters, cv=5)

# %%
GCV.fit(xtrain, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 20, 30, 40],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %%
GCV.best_params_
# Out:
# {'max_depth': 20,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5}

# %%
model = RandomForestClassifier(max_depth = 20, max_features = 'sqrt', min_samples_leaf = 1, min_samples_split = 5)
model.fit(xtrain, ytrain)
pred = model.predict(xtest)
acc = accuracy_score(ytest,pred)
print(acc*100)
# Out:
# 97.29441082235671

# %% [markdown]
# <b>After Hyperparameter Tuning, we got an accuracy score of 97.29%</b>

# %% [markdown]
# # Plotting ROC-AUC curve for the best model

# %%
from sklearn import datasets 
from sklearn import metrics
from sklearn import model_selection

x,y = datasets.make_classification (random_state=maxRS)
xtrain, xtest, ytrain, ytest = model_selection.train_test_split(x, y, random_state=maxRS)
data = RandomForestClassifier(random_state=maxRS)
data.fit(xtrain, ytrain)
metrics.plot_roc_curve(data, xtest, ytest)
plt.show()

# %% [markdown]
# # Saving the model

# %%
import joblib

joblib.dump(model,'Price range')
# Out:
# ['Price range']

# %%
loadmodel = joblib.load('Price range')

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
